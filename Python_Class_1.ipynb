# %% [markdown]
# <a href="https://colab.research.google.com/github/Sarasvathi24/Python-Notes-/blob/main/Python_Class_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Science
#
#  **Python Lesson 1**

# %% [markdown]
# ***Saras***

# %% [markdown]
# [LinkediIn](https://www.linkedin.com/in/sarasvathi-sivam/)

# %% [markdown]
# ![2021-02-02 (5).png](data:image/png;base64,...)

# %%
#Variable a,b,c
a = 10
b = 20

c = a*b
print(c)
# Out:
# 200

# %%
print(c)
# Out:
# 200

# %%
c = a+b

# %%
print(c)
# Out:
# 30

# %%
import pandas as pd

df = pd.read_csv('NFLX.csv')

#to read first five rows of the file

df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2015-12-16  119.800003  123.000000  118.089996  122.639999  122.639999
# 1  2015-12-17  123.970001  126.349998  122.419998  122.510002  122.510002
# 2  2015-12-18  120.849998  122.190002  117.919998  118.019997  118.019997
# 3  2015-12-21  119.510002  119.589996  115.660004  116.629997  116.629997
# 4  2015-12-22  117.300003  117.430000  114.860001  116.239998  116.239998
#
#      Volume
# 0  13181000
# 1  17284900
# 2  17948100
# 3  11670000
# 4   9689000

# %%
#to read more than 5 rows, hence mention the number of rows we want to read

df.head(10)
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2015-12-16  119.800003  123.000000  118.089996  122.639999  122.639999
# 1  2015-12-17  123.970001  126.349998  122.419998  122.510002  122.510002
# 2  2015-12-18  120.849998  122.190002  117.919998  118.019997  118.019997
# 3  2015-12-21  119.510002  119.589996  115.660004  116.629997  116.629997
# 4  2015-12-22  117.300003  117.430000  114.860001  116.239998  116.239998
# 5  2015-12-23  116.910004  118.559998  115.779999  118.160004  118.160004
# 6  2015-12-24  118.220001  118.800003  117.300003  117.330002  117.330002
# 7  2015-12-28  117.260002  117.349998  113.849998  117.110001  117.110001
# 8  2015-12-29  118.190002  119.599998  116.919998  119.120003  119.120003
# 9  2015-12-30  118.949997  119.019997  116.430000  116.709999  116.709999
#
#      Volume
# 0  13181000
# 1  17284900
# 2  17948100
# 3  11670000
# 4   9689000
# 5   9324300
# 6   3531300
# 7   8424300
# 8   8159200
# 9   8149700

# %%
# to read the last 5 rows from the csv file
df.tail()
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 1002  2019-12-10  296.119995  298.940002  292.019989  293.119995  293.119995
# 1003  2019-12-11  294.489990  299.429993  294.200012  298.929993  298.929993
# 1004  2019-12-12  295.670013  299.170013  295.059998  298.440002  298.440002
# 1005  2019-12-13  298.500000  301.799988  297.250000  298.500000  298.500000
# 1006  2019-12-16  300.850006  305.709991  298.630005  304.209991  304.209991
#
#         Volume
# 1002  10476100
# 1003   5589800
# 1004   4766600
# 1005   3879700
# 1006   4658900

# %%
#to read last 10 rows
df.tail(10)
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 997   2019-12-03  302.220001  307.359985  301.880005  306.160004  306.160004
# 998   2019-12-04  308.429993  308.429993  303.269989  304.320007  304.320007
# 999   2019-12-05  305.269989  306.480011  298.809998  302.859985  302.859985
# 1000  2019-12-06  304.700012  307.850006  302.600006  307.350006  307.350006
# 1001  2019-12-09  307.350006  311.489990  302.440002  302.500000  302.500000
# 1002  2019-12-10  296.119995  298.940002  292.019989  293.119995  293.119995
# 1003  2019-12-11  294.489990  299.429993  294.200012  298.929993  298.929993
# 1004  2019-12-12  295.670013  299.170013  295.059998  298.440002  298.440002
# 1005  2019-12-13  298.500000  301.799988  297.250000  298.500000  298.500000
# 1006  2019-12-16  300.850006  305.709991  298.630005  304.209991  304.209991
#
#         Volume
# 997    4992800
# 998    3512100
# 999    4615500
# 1000   4457800
# 1001   5748400
# 1002  10476100
# ...

# %%
# (1007 - last row, 7 - last column/feature) based on the file
df.shape
# Out:
# (1007, 7)

# %% [markdown]
# **Python Data Types**
#
# 1.   Integer
# 2. String
# 3. Float

# %%
#Some books may say: Integer, Float & Complex

#complex
a = 3 + 5*b

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
#single code/double code - python will consider as string
type('2024')
# Out:
# str

# %% [markdown]
# **Boolean Data Types**
#
# * True
# * False

# %%
type(True)
# Out:
# bool

# %%
type(true)

#know the error from the last line
#Python will consider it as variable and not boolean
#Case sensitive
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-be63b14aa6c4> in <cell line: 1>()
# ----> 1 type(true)
#       2
#       3 #know the error from the last line
#       4 #Python will consider it as variable and not boolean
#
# NameError: name 'true' is not defined

# %% [markdown]
# *Expressions, Variables, Conditions*
#
# <ul>
#     <li>subtraction: <b>-</b></li>
#     <li>addition: <b>+</b></li>
#     <li>division: <b>/</b></li>
#     <li>floor division <b>//</b></li>
#     <li>multiplication: <b>*</b></li>
#     <li>modulus: <b>%</b></li>
#     <li>exponent: <b></b></li>
# </ul>

# %%
x = 8
z = 2

y = x / z

y
# Out:
# 4.0

# %%
type(y)
# Out:
# float

# %%
y = x // z

# %%
y
# Out:
# 4

# %%
type(y)
# Out:
# int

# %%
d = 8
c = 3

f = d / c

f
# Out:
# 2.6666666666666665

# %%
#Division = result will be in float
#Floor Division = result will be in integer

f = d // c

f
# Out:
# 2

# %%
#Modulous - reminder of division

b1 = 10%3
b2 = 10%2
b3 = 11%2
b4 = 11%3

print(b1)
print(b2)
print(b3)
print(b4)
# Out:
# 1
# 0
# 1
# 2

# %%
#Exponent - 2 times 2 times 2
2**3
# Out:
# 8

# %% [markdown]
# **Variables**

# %%
#Avoid using same name of built-in functions
#Avoid using same variable many times
#No space - should be 1 word (if more than 1 word can use underscore)
#No integers or float as variables

type = 'big data'

# %%
type(20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-5b1f786095c8> in <cell line: 1>()
# ----> 1 type(20)
#
# TypeError: 'str' object is not callable

# %%
machine learning = 'Data Science'
# Out:
#   File "<ipython-input-25-90a1c9da181f>", line 1
#     machine learning = 'Data Science'
#             ^
# SyntaxError: invalid syntax

# %%
machine_learning = 'Data Science'

# %%
machine_learning
# Out:
# 'Data Science'

# %%
#detecting variables that has been used throught in the code
# %whos
# Out:
# Variable           Type    Data/Info
# ------------------------------------
# b1                 int     1
# b2                 int     0
# b3                 int     1
# b4                 int     2
# c                  int     3
# d                  int     8
# f                  int     2
# machine_learning   str     Data Science
# type               str     big data
# x                  int     8
# y                  int     4
# z                  int     2

# %% [markdown]
# **Conditions**
#
# <ul>
#     <li>equal: <b>==</b></li>
#     <li>not equal: <b>!=</b></li>
#     <li>greater than: <b>></b></li>
#     <li>less than: <b>&lt;</b></li>
#     <li>greater than or equal to: <b>>=</b></li>
#     <li>less than or equal to: <b>&lt;=</b></li>
# </ul>

# %%
#double == means we are asking

year = 2024

year == 2024
# Out:
# True

# %%
year != 2025
# Out:
# True

# %%
year == 2026
# Out:
# False

# %% [markdown]
# # **Python Lesson 2**
#
# **String Indexing**

# %%
#Number in sequel bracket - to only print that particular number
singer = 'Michael Jackson'

print(singer)
print(singer[2])
print(singer[5])
print(singer[10])
print(singer[13])
# Out:
# Michael Jackson
# c
# e
# c
# o

# %%
#Indexing from front starts from 0
#Space in between words will also counted as index

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/Chapter%201/Images/StringsIndex.png" width="600" align="center" />

# %%
#Backward Indexing starts from -1
#Space in between words will also counted as index

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/Chapter%201/Images/StringsNeg.png" width="600" align="center" />

# %%
print(singer[-13])
print(singer[-10])
print(singer[-2])
# Out:
# c
# e
# o

# %%
#print the last, second last, first and second of any string

#first
print(anystring[0])
#second
print(anystring[1])
#last
print(anystring[-1])
#second last
print(anystring[-2])

# %% [markdown]
# **Index Slicing**

# %%
print(anystring[index to start from: index to stop])

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/Chapter%201/Images/StringsIndex.png" width="600" align="center" />

# %%
print(singer[0:6])
# Out:
# Michae

# %%
#For index stop at, you should mention in an advance (+1) - since it will consider counting start from 1
print(singer[0:7])
# Out:
# Michael

# %%
print(singer[:7])
# Out:
# Michael

# %%
#printing Jackson
#printed with space

print(singer[7:])
# Out:
#  Jackson

# %%
print(singer[8:])
# Out:
# Jackson

# %%
#printing from backward

print(singer[-7:])
# Out:
# Jackson

# %%
print(singer[8:15])
# Out:
# Jackson

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/Chapter%201/Images/StringsIndex.png" width="600" align="center" />

# %%
print(singer[:7:2])
# Out:
# Mcal

# %%
print(singer[:7:3])
# Out:
# Mhl

# %% [markdown]
# **Concatenating String**

# %%
#Concatenate = bringing 2 things together
#not summing, its concatenating

str1 = 'Big'
str2 = 'Data'
str3 = str1 + str2

print(str3)
# Out:
# BigData

# %%
str4 = str2 + str1

print(str4)
# Out:
# DataBig

# %%
str3 = str1 + ' ' + str2

print(str3)
# Out:
# Big Data

# %%
#cannot concatenate from diff data types
str5 = str1 + 2024

str5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-88e0f1d172ed> in <cell line: 2>()
#       1 #cannot concatenate from diff data types
# ----> 2 str5 = str1 + 2024
#       3
#       4 str5
#
# TypeError: can only concatenate str (not "int") to str

# %%
#concatenating is only among strings
str5 = str1 + '2024'

# %%
str5
# Out:
# 'Big2024'

# %%
str6 = '2024'

print(str6)
# Out:
# 2024

# %%
type(str6)
# Out:
# str

# %%
#changing the type of data set

str7 = int(str6)

print(str7)
# Out:
# 2024

# %%
type(str7)
# Out:
# int

# %%
str8 = float(str7)

print(str8)
# Out:
# 2024.0

# %%
str9 = float(str1)

str9
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-76a3a276250c> in <cell line: 1>()
# ----> 1 str9 = float(str1)
#       2
#       3 str9
#
# ValueError: could not convert string to float: 'Big'

# %%
#converting 999 (integer) to string and then change the type again to integer
test1 = int(str(999))

test1
# Out:
# 999

# %%
type(test1)
# Out:
# int

# %%
#read the code from back - the float of 999.0 change to integer (999) and then change to string ('999)
test2 = str(int(float(999)))
print(test2)

type(test2)
# Out:
# 999
# str

# %% [markdown]
# **Python Data Structure**
#
# * List[]
# * Tuple ()
# * Set {}
# * Dictionary {}

# %%
#List - sequel bracket
l1 = [8.8, 'Data Science', 2024, 99, -20]
#tuple
t1 = (8.8, 'Data Science', 2024, 99, -20)
#Set - curly bracket
s1 = {8.8, 'Data Science', 2024, 99, -20}

print(l1)
print(t1)
print(s1)
# Out:
# [8.8, 'Data Science', 2024, 99, -20]
# (8.8, 'Data Science', 2024, 99, -20)
# {99, 'Data Science', 8.8, 2024, -20}

# %%
type(l1)
# Out:
# list

# %%
type(t1)
# Out:
# tuple

# %%
type(s1)
# Out:
# set

# %%
#index

print(l1[2])
print(l1[2:])
# Out:
# 2024
# [2024, 99, -20]

# %%
type(l1[2])
# Out:
# int

# %%
type(l1[2:])
# Out:
# list

# %%
#extend - adding items in the list at the end

l1.extend([55, 'AI'])

l1
# Out:
# [8.8, 'Data Science', 2024, 99, -20, 55, 'AI']

# %%
#append - adding items in the list at the end - as another list (nested list)
#the new nested list has only 1 index

l1.append(['ML', 999])
l1
# Out:
# [8.8, 'Data Science', 2024, 99, -20, 55, 'AI', ['ML', 999]]

# %%
#nested list - the main list will consider the newly added list as one item/1 index

print(l1[-1])
# Out:
# ['ML', 999]

# %%
print(l1[-1][-1])
# Out:
# 999

# %%
l2 = [8.8, 'Data Science', 2024, 99, -20, 55, 'AI', ['ML', 999, ['A','B','C']]]

#PRINT THE LETTER B & C

print(l2[-1][-1][-2])
print(l2[-1][-1][-1])
print(l2[-1][-1][-2:])
# Out:
# B
# C
# ['B', 'C']

# %%
#del
#based on index
#if run this cod again, 2024 will be removed - to undo (run the l1 code above)
del(l1[1])

l1
# Out:
# [8.8, 99, -20, 55, 'AI', ['ML', 999]]

# %%
#find an index of an item in a list

l1.index('AI')
# Out:
# 4

# %%
#counting the frequency of an item in a list - how many times the item repated in the list

l3 = [20, 200, 99, 20,'AI', 20, 'AI', 20]

#function count

l3.count(20)
# Out:
# 4

# %%
l3.count('AI')
# Out:
# 2

# %%
#remove - deleting an item by not mentioning index
#if run again can delete another ('AI') and if run again it will be error since there is no more ('AI')

l3.remove('AI')

# %%
l3
# Out:
# [20, 200, 99, 20, 20, 'AI', 20]

# %%
#insert

#list.insert(index,adding item)

l3.insert(4,'AI')

l3
# Out:
# [20, 200, 99, 20, 'AI', 20, 'AI', 20]

# %%
#reverse

l3.reverse()

l3
# Out:
# [20, 'AI', 20, 'AI', 20, 99, 200, 20]

# %%
#sort - ascending order

l3.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-a9371c2c8d85> in <cell line: 3>()
#       1 #sort - ascending order
#       2
# ----> 3 l3.sort()
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
l3.remove('AI')

l3
# Out:
# [20, 20, 20, 99, 200, 20]

# %%
l3.sort()

# %%
l3
# Out:
# [20, 20, 20, 20, 99, 200]

# %%
#can sort in ascendinf order first - if want descending then use reverse function

l3.reverse()

l3
# Out:
# [200, 99, 20, 20, 20, 20]

# %%
#length

len(l3)
# Out:
# 6

# %%
l4 = [20, 0, -5, 13, -1, 7, 4, -3, 17,9]

#sort l4 in ascending and descending
#print the highest value and lowest value
l3.sort()
l3
# Out:
# [20, 20, 20, 20, 99, 200]

# %%
l3.reverse()
l3
# Out:
# [200, 99, 20, 20, 20, 20]

# %%
print ('The highest value is ', l4[0])
print ('The lowest value is ', l4[-1])
# Out:
# The highest value is  20
# The lowest value is  9

# %% [markdown]
# ### List
# - *Mutable*: You can change the elements (add, remove, or modify) after the list is created.
# - *Syntax*: Defined using square brackets [].
#   python
#   my_list = [1, 2, 3]
#
# - *Performance*: Slightly slower due to the flexibility of mutability.
# - *Use Case*: Best when you need a collection of items that may change over time.
#
# ### Tuple
# - *Immutable*: Once created, you cannot change the elements (no adding, removing, or modifying).
# - *Syntax*: Defined using parentheses ().
#   python
#   my_tuple = (1, 2, 3)
#
# - *Performance*: Faster than lists due to immutability.
# - *Use Case*: Best when you need a collection of items that should not change, ensuring data integrity.
#
# ### Key Differences
# 1. *Mutability*:
#    - Lists: Mutable
#    - Tuples: Immutable
#
# 2. *Syntax*:
#    - Lists: []
#    - Tuples: ()
#
# 3. *Performance*:
#    - Lists: Slower due to overhead of mutable operations.
#    - Tuples: Faster due to immutability.
#
# 4. *Use Cases*:
#    - Lists: Collections of items that need to be changed or updated.
#    - Tuples: Fixed collections of items that should not change after creation.
#
# ### Example
# #### List
# python
# my_list = [1, 2, 3]
# my_list.append(4)
# print(my_list)  # Output: [1, 2, 3, 4]
#
#
# #### Tuple
# python
# my_tuple = (1, 2, 3)
# # my_tuple.append(4)  # This will raise an AttributeError
# print(my_tuple)  # Output: (1, 2, 3)
#
#
# ### Summary
# - Use *lists* when you need a dynamic collection that may change over time.
# - Use *tuples* when you need a fixed collection of items that should remain constant.

# %%
t1
# Out:
# (8.8, 'Data Science', 2024, 99, -20)

# %%
print(t1[2])
# Out:
# 2024

# %%
#nested tuple

t2 = (8.8, 'Data Science', (2024, 99), -20)

print(t2[-2][-1])
# Out:
# 99

# %%
t3 = ('AI','Python')
tnew = t2 + t3

tnew
# Out:
# (8.8, 'Data Science', (2024, 99), -20, 'AI', 'Python')

# %%
t4 = (5, 88, -20, 99, 30, 8.8, 0, 5)

#sorted
#comvert th tuple to a list and sort it - so the result is in list
sort_t4 = sorted(t4)

print(sort_t4)
# Out:
# [-20, 0, 5, 5, 8.8, 30, 88, 99]

# %%
#Built-in function to change tuple to list

list_t4 = list(t4)

list(t4)
# Out:
# [5, 88, -20, 99, 30, 8.8, 0, 5]

# %%
tuple_list_t4 = tuple(list_t4)

tuple_list_t4
# Out:
# (5, 88, -20, 99, 30, 8.8, 0, 5)

# %%
t5 = ('AI', 'Data', 2024, 'ML')
list_new_items = [888, 'Python', 'DL']

#create a new tuple of the aboveand list
#Cara 1
New_list = list(t5) + list_new_items

New_list
# Out:
# ['AI', 'Data', 2024, 'ML', 888, 'Python', 'DL']

# %%
t6 = tuple(New_list)

t6
# Out:
# ('AI', 'Data', 2024, 'ML', 888, 'Python', 'DL')

# %%
t5 = ('AI', 'Data', 2024, 'ML')
list_new_items = [888, 'Python', 'DL']

#create a new tuple of the aboveand list
#Cara 1

list_t5 = list(t5)
list_t5.extend(list_new_items)

list_t5
# Out:
# ['AI', 'Data', 2024, 'ML', 888, 'Python', 'DL']

# %%
new_tuple = tuple(list_t5)

new_tuple
# Out:
# ('AI', 'Data', 2024, 'ML', 888, 'Python', 'DL')
